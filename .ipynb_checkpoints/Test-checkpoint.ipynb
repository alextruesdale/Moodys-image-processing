# %%
# %%javascript
# if($(IPython.toolbar.selector.concat(' > #kill-run-all')).length == 0){
#   IPython.toolbar.add_buttons_group([
#         {
#              'label'   : 'kill and run-all2',
#              'icon'    : 'fa fa-angle-double-down',
#              'callback': function(){
#                  IPython.notebook.kernel.restart();
#                  $(IPython.events).one('kernel_ready.Kernel',
#                                        function(){IPython.notebook.execute_all_cells();});
#              }
#         }
#     ], 'kill-run-all');
# }

# %%
"""Top-level project Main function."""

import ImageReader
import PostOperator
import time
import os

os.chdir("/Users/alextruesdale/Documents/Horizontal_Crop")

# %%
def main():
    """Read file directory images and the run the Image Operator aggregate function."""

    files = ImageReader.read_files('include', 'cut')
    
    for file in files:
        print(file)
        PostOperator.PostOperator(file)

# %%
main()
# Out:
# /Users/alextruesdale/Documents/Horizontal_Crop/Test/output/input/folder/three-column/Banks19380027-0087/cut1/vertical_cut_Banks19380027-0087.tif
# mean: values    0.708169
# dtype: float64
# sdev: values    0.089563
# dtype: float64
# mean + 1.5 sdev: values    0.842513
# dtype: float64
# mean - 2 sdev: values    0.529042
# dtype: float64
# [185, 310, 728, 1548, 1651, 1792, 1963, 2916, 3720, 3821, 4080]
# [214, 248, 284, 1690, 1723, 1760, 3020]
# /Users/alextruesdale/Documents/Horizontal_Crop/Test/output/input/folder/three-column/Banks19380027-0087/cut2/vertical_cut_Banks19380027-0087.tif
# mean: values    0.737814
# dtype: float64
# sdev: values    0.093304
# dtype: float64
# mean + 1.5 sdev: values    0.87777
# dtype: float64
# mean - 2 sdev: values    0.551205
# dtype: float64
# [216, 287, 314, 390, 558, 736, 804, 1265, 1283, 1370, 1544, 2500, 3604, 4076]
# [1408, 1578, 2540, 2574, 2610, 4034]
# ...
