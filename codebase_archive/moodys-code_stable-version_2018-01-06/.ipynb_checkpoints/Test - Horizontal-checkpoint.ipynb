# %%
# %%javascript
# if($(IPython.toolbar.selector.concat(' > #kill-run-all')).length == 0){
#   IPython.toolbar.add_buttons_group([
#         {
#              'label'   : 'kill and run-all2',
#              'icon'    : 'fa fa-angle-double-down',
#              'callback': function(){
#                  IPython.notebook.kernel.restart();
#                  $(IPython.events).one('kernel_ready.Kernel',
#                                        function(){IPython.notebook.execute_all_cells();});
#              }
#         }
#     ], 'kill-run-all');
# }

# %%
"""Top-level project Main function."""

import os
import Main

os.chdir("/Users/alextruesdale/Documents/moodys_drafts/straighten_check")

# %%
Main.main()
# Out:
# /Users/alextruesdale/Documents/moodys_drafts/straighten_check/folder/0001/Industrial19230001-0001.tif
# gutter threshold: 0.9299999999999999
#         values
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     0.940154
# 10    0.939483
# 11    0.938555
# 12    0.937541
# 13    0.936844
# 14    0.936557
# 15    0.936530
# 16    0.936686
# 17    0.936911
# 18    0.937022
# 19    0.937116
# 20    0.937187
# 21    0.937338
# 22    0.937480
# 23    0.937476
# 24    0.937490
# 25    0.937588
# 26    0.937678
# 27    0.937771
# 28    0.937691
# 29    0.937501
# ...        ...
# 3150  0.917295
# 3151  0.917611
# 3152  0.917775
# 3153  0.917837
# 3154  0.917882
# 3155  0.917700
# 3156  0.917693
# 3157  0.917698
# 3158  0.917640
# 3159  0.917849
# 3160  0.917947
# 3161  0.917688
# 3162  0.917431
# 3163  0.917470
# 3164  0.917493
# 3165  0.917535
# 3166  0.917680
# 3167  0.917706
# 3168  0.917487
# 3169  0.917353
# 3170  0.917301
# 3171  0.917256
# 3172  0.917370
# 3173  0.917254
# 3174  0.917263
# 3175  0.917300
# 3176  0.917181
# 3177  0.917140
# 3178  0.917092
# 3179  0.917119
#
# [3180 rows x 1 columns]
# Duration: 4.43 seconds
# /Users/alextruesdale/Documents/moodys_drafts/straighten_check/folder/0001/Industrial19230001-0002.tif
# gutter threshold: 0.94
#         values
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     0.950228
# 10    0.950224
# 11    0.950210
# 12    0.950223
# 13    0.950220
# 14    0.950288
# 15    0.950321
# 16    0.950342
# 17    0.950388
# 18    0.950386
# 19    0.950456
# 20    0.950543
# 21    0.950568
# 22    0.950532
# 23    0.950510
# 24    0.950474
# 25    0.950440
# 26    0.950417
# 27    0.950423
# 28    0.950396
# 29    0.950328
# ...        ...
# 3181  0.915441
# 3182  0.915312
# 3183  0.915265
# 3184  0.915172
# 3185  0.915023
# 3186  0.915000
# 3187  0.914909
# 3188  0.914793
# 3189  0.914773
# 3190  0.914663
# 3191  0.914523
# 3192  0.914418
# 3193  0.914382
# 3194  0.914326
# 3195  0.914242
# 3196  0.914083
# 3197  0.914033
# 3198  0.914056
# 3199  0.913966
# 3200  0.913938
# 3201  0.913998
# 3202  0.914045
# 3203  0.914061
# 3204  0.914129
# 3205  0.914281
# 3206  0.914498
# 3207  0.914631
# 3208  0.914711
# 3209  0.914841
# 3210  0.914953
#
# [3211 rows x 1 columns]
# Duration: 4.17 seconds
# /Users/alextruesdale/Documents/moodys_drafts/straighten_check/folder/0001/Industrial19230001-0003.tif
# gutter threshold: 0.94
#         values
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     0.955955
# 10    0.955658
# 11    0.955355
# 12    0.954942
# 13    0.954515
# 14    0.954105
# 15    0.953688
# 16    0.953212
# 17    0.952722
# 18    0.952197
# 19    0.951591
# 20    0.951126
# 21    0.950666
# 22    0.950215
# 23    0.949924
# 24    0.949566
# 25    0.949164
# 26    0.948813
# 27    0.948626
# 28    0.948357
# 29    0.948199
# ...        ...
# 3164  0.936407
# 3165  0.936242
# 3166  0.936079
# 3167  0.935807
# 3168  0.935593
# 3169  0.935418
# 3170  0.935286
# 3171  0.935109
# 3172  0.935067
# 3173  0.935004
# 3174  0.934949
# 3175  0.934918
# 3176  0.934847
# 3177  0.934814
# 3178  0.934903
# 3179  0.934891
# 3180  0.934789
# 3181  0.934795
# 3182  0.934705
# 3183  0.934662
# 3184  0.934646
# 3185  0.934639
# 3186  0.934623
# 3187  0.934759
# 3188  0.934759
# 3189  0.934836
# 3190  0.934997
# 3191  0.935111
# 3192  0.935263
# 3193  0.935442
#
# [3194 rows x 1 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     475     try:
# --> 476         fh = fp.fileno()
#     477         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8d6d2fabc621> in <module>()
# ----> 1 Main.main()
#
# ~/Documents/moodys_drafts/horizontal_crop/Test/jupyter_notebooks/Main.py in main()
#      22         print(file)
#      23         try:
# ---> 24             ImageOperator.ImageOperator(file)
#      25         except Exception as e:
#      26             logger.error('\n\n' + 'File: ' + file + '\n' + 'Error Message: ' +
#
# ~/Documents/moodys_drafts/horizontal_crop/Test/jupyter_notebooks/ImageOperator.py in __init__(self, file)
#      26         self.file = file
#      27         self.rotated_image = ImageRotater.ImageRotater(self.file)
# ---> 28         self.cropped_image_full = ImageCropper.ImageCropper(self.rotated_image)
#      29         self.horizontal_gutter_test = ImageColumnCropper.ImageColumnCropper(self.rotated_image,
#      30                                                                             self.cropped_image_full,
#
# ~/Documents/moodys_drafts/horizontal_crop/Test/jupyter_notebooks/ImageCropper.py in __init__(self, rotated_image)
#      26         self.cropped_array = self.rotate_crop_data[0]
#      27         self.page_number_array = self.rotate_crop_data[1]
# ---> 28         self.final_cropped_array = self.trim_sides()
#      29
#      30     def rotate_crop(self):
#
# ~/Documents/moodys_drafts/horizontal_crop/Test/jupyter_notebooks/ImageCropper.py in trim_sides(self)
#     196
#     197         trimmed_image = self.cropped_array[:, crop_points[0] : crop_points[1]]
# --> 198         Image.fromarray(trimmed_image).show()
#     199         return trimmed_image
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in show(self, title, command)
#    1973         """
#    1974
# -> 1975         _show(self, title=title, command=command)
#    1976
#    1977     def split(self):
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in _show(image, **options)
#    2787 def _show(image, **options):
#    2788     # override me, as necessary
# -> 2789     _showxv(image, **options)
#    2790
#    2791
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in _showxv(image, title, **options)
#    2792 def _showxv(image, title=None, **options):
#    2793     from . import ImageShow
# -> 2794     ImageShow.show(image, title, **options)
#    2795
#    2796
#
# /usr/local/lib/python3.6/site-packages/PIL/ImageShow.py in show(image, title, **options)
#      49     """
#      50     for viewer in _viewers:
# ---> 51         if viewer.show(image, title=title, **options):
#      52             return 1
#      53     return 0
#
# /usr/local/lib/python3.6/site-packages/PIL/ImageShow.py in show(self, image, **options)
#      73             image = image.convert(base)
#      74
# ---> 75         return self.show_image(image, **options)
#      76
#      77     # hook methods
#
# /usr/local/lib/python3.6/site-packages/PIL/ImageShow.py in show_image(self, image, **options)
#      93     def show_image(self, image, **options):
#      94         """Display given image"""
# ---> 95         return self.show_file(self.save_image(image), **options)
#      96
#      97     def show_file(self, file, **options):
#
# /usr/local/lib/python3.6/site-packages/PIL/ImageShow.py in save_image(self, image)
#      89     def save_image(self, image):
#      90         """Save to temporary file, and return filename"""
# ---> 91         return image._dump(format=self.get_format(image), **self.options)
#      92
#      93     def show_image(self, image, **options):
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in _dump(self, file, format, **options)
#     620             self.im.save_ppm(filename)
#     621         else:
# --> 622             self.save(filename, format, **options)
#     623
#     624         return filename
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1926
#    1927         try:
# -> 1928             save_handler(self, fp, filename)
#    1929         finally:
#    1930             # do what we can to clean up
#
# /usr/local/lib/python3.6/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, check)
#     795
#     796     ImageFile._save(im, _idat(fp, chunk),
# --> 797                     [("zip", (0, 0)+im.size, 0, rawmode)])
#     798
#     799     chunk(fp, b"IEND", b"")
#
# /usr/local/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     488             else:
#     489                 while True:
# --> 490                     l, s, d = e.encode(bufsize)
#     491                     fp.write(d)
#     492                     if s:
#
# KeyboardInterrupt:
