# %%
# %%javascript
# if($(IPython.toolbar.selector.concat(' > #kill-run-all')).length == 0){
#   IPython.toolbar.add_buttons_group([
#         {
#              'label'   : 'kill and run-all2',
#              'icon'    : 'fa fa-angle-double-down',
#              'callback': function(){
#                  IPython.notebook.kernel.restart();
#                  $(IPython.events).one('kernel_ready.Kernel',
#                                        function(){IPython.notebook.execute_all_cells();});
#              }
#         }
#     ], 'kill-run-all');
# }

# %%
"""Top-level project Main function."""

import os
import Main

os.chdir("/Users/alextruesdale/Documents/moodys_code/straighten_check/folder")

# %%
Main.main()
# Out:
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0007.tif
# [54, 2926, 137, 3999]
# vertical_test
# 0.9299999999999999
# []
# horizontal_run
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [3713, 3545, 3372, 3124, 3000, 2898, 2798, 2700, 2597, 2496, 2379, 2228, 2081, 1936, 1791, 1646, 1502, 1355, 1211, 1067, 919, 800, 674, 531, 373]
# vertical_run
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [2404, 2190, 1441, 1219, 598]
# 0.9299999999999999
# []
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1422, 1344, 1237, 1151, 1071, 979, 871, 736, 596]
# 0.9299999999999999
# []
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [981, 856, 633, 537, 467]
# 0.9299999999999999
# sub_test_running
# [847]
# 0.9299999999999999
# sub_test_running
# [856]
# 0.9299999999999999
# sub_test_running
# [630]
# 0.9299999999999999
# sub_test_running
# [1814]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# [1423, 849, 655]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# [861, 741, 656]
# 0.9299999999999999
# []
# 0.9299999999999999
# sub_test_running
# sub_test_running
# [861, 787]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1829, 1426, 865, 755, 582]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1813, 1429, 1158, 1086, 985, 867, 754, 585]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1427, 1091, 852, 625]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1428, 1091, 985, 877, 757, 621, 540]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1427, 1243, 1161, 1081, 921, 747, 597]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1817, 1430, 1336, 1154, 911, 615]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1806, 1608, 1430, 1350, 1240, 642]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# [1818, 1432]
# 0.9299999999999999
# sub_test_running
# [1435]
# 0.9299999999999999
# sub_test_running
# [1511]
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1816, 1699, 1520, 1432, 989, 864, 761, 646, 493]
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# Duration: 32.18 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0008.tif
# [81, 2952, 75, 3527]
# vertical_test
# 0.9299999999999999
# []
# horizontal_run
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [2729, 1998, 1601, 802, 270]
# vertical_run
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# Duration: 7.22 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0009.tif
# [187, 3056, 0, 3313]
# vertical_test
# 0.9299999999999999
# []
# horizontal_run
# 0.9299999999999999
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [2187, 1657, 1059, 666, 339]
# vertical_run
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# 0.9299999999999999
# []
# Duration: 7.05 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0010.tif
# [82, 2949, 140, 3102]
# vertical_test
# 0.9299999999999999
# sub_test_running
# [1437]
# vertical_run
# 0.9299999999999999
# sub_test_running
# [1437]
# Duration: 5.23 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0011.tif
# [138, 3008, 44, 3980]
# vertical_test
# 0.9299999999999999
# sub_test_running
# [1437]
# vertical_run
# 0.9299999999999999
# sub_test_running
# [1437]
# Duration: 6.42 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0012.tif
# [81, 2952, 38, 3949]
# vertical_test
# 0.9299999999999999
# sub_test_running
# [1436]
# vertical_run
# 0.9299999999999999
# sub_test_running
# [1436]
# Duration: 6.03 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0013.tif
# [115, 2990, 34, 3956]
# vertical_test
# 0.9299999999999999
# sub_test_running
# [1442]
# vertical_run
# 0.9299999999999999
# sub_test_running
# [1442]
# Duration: 5.24 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0014.tif
# [82, 2960, 34, 3982]
# vertical_test
# 0.9199999999999999
# sub_test_running
# [1438]
# vertical_run
# 0.9199999999999999
# sub_test_running
# [1438]
# Duration: 5.59 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0015.tif
# [159, 3024, 142, 3248]
# vertical_test
# 0.96
# sub_test_running
# [1434]
# vertical_run
# 0.96
# sub_test_running
# [1434]
# Duration: 3.31 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0016.tif
# [95, 2960, 40, 3964]
# vertical_test
# 0.96
# sub_test_running
# [1433]
# vertical_run
# 0.96
# sub_test_running
# [1433]
# Duration: 3.6 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0017.tif
# [167, 3031, 37, 2004]
# vertical_test
# 0.96
# sub_test_running
# [1432]
# vertical_run
# 0.96
# sub_test_running
# [1432]
# Duration: 2.81 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0018.tif
# [2, 2879, 68, 4087]
# vertical_test
# 0.96
# []
# horizontal_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [3877, 2224, 1799, 925]
# vertical_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1716, 1327, 723, 422]
# 0.96
# []
# 0.96
# []
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [2448, 2022, 1825, 764, 565]
# 0.96
# sub_test_running
# []
# Duration: 7.09 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0019.tif
# [186, 3062, 32, 3969]
# vertical_test
# 0.96
# sub_test_running
# []
# horizontal_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [3173]
# vertical_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# [984, 647]
# 0.96
# sub_test_running
# []
# Duration: 5.42 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0020.tif
# [49, 2926, 34, 3982]
# vertical_test
# 0.96
# []
# horizontal_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [2803, 2430, 1803]
# vertical_run
# 0.96
# []
# 0.96
# []
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [2416, 2207, 1978, 1438, 1244, 973, 749, 516]
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [1504]
# Duration: 8.65 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0021.tif
# [148, 3051, 33, 3982]
# vertical_test
# 0.96
# []
# horizontal_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [2891, 2144, 1803]
# vertical_run
# 0.96
# []
# 0.96
# sub_test_running
# sub_test_running
# [2303, 1824]
# 0.96
# []
# 0.96
# []
# Duration: 5.49 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0022.tif
# [41, 2920, 33, 3985]
# vertical_test
# 0.96
# []
# horizontal_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [3759, 1902]
# vertical_run
# 0.96
# []
# 0.96
# []
# 0.96
# sub_test_running
# []
# Duration: 4.6 seconds
# /Users/alextruesdale/Documents/moodys_code/straighten_check/folder/0001/Industrial19230001-0023.tif
# [181, 3083, 35, 3988]
# vertical_test
# 0.96
# []
# horizontal_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# CUTPOINTS [3589, 3262, 2817, 1654, 549]
# vertical_run
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# [2289, 784, 447]
# 0.96
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# sub_test_running
# [2294, 1991, 1692, 1394, 1092, 787, 497]
# 0.96
# []
# 0.96
# []
# 0.96
# sub_test_running
# []
# 0.96
# sub_test_running
# sub_test_running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8d6d2fabc621> in <module>()
# ----> 1 Main.main()
#
# ~/Documents/moodys_code/horizontal_crop/codebase/Main.py in main()
#      22         print(file)
#      23         try:
# ---> 24             ImageOperator.ImageOperator(file, files_operated)
#      25         except Exception as e:
#      26             logger.error('\n\n' + 'File: ' + file + '\n' + 'Error Message: ' +
#
# ~/Documents/moodys_code/horizontal_crop/codebase/ImageOperator.py in __init__(self, file, files_operated)
#      38         self.image_to_columns = ImageVerticalCrop(self.rotated_image,
#      39                                                   self.horizontal_gutter_test,
# ---> 40                                                   False)
#      41
#      42         self.image_meta_data = ImageMetaRead(self.file,
#
# ~/Documents/moodys_code/horizontal_crop/codebase/ImageVerticalCrop.py in __init__(self, rotated_image, array_input, test_value)
#      19         self.page_number_array = array_input.page_number_array
#      20         self.threshold = rotated_image.threshold
# ---> 21         self.output_data = self.column_crop_operate(test_value)
#      22         self.cutpoints = self.output_data[0]
#      23         self.output_images = self.output_data[1]
#
# ~/Documents/moodys_code/horizontal_crop/codebase/ImageVerticalCrop.py in column_crop_operate(self, test_value)
#     114
#     115             cutpoints_initial = ImageColumnCropOperators.find_cutpoints(
# --> 116                                 image_array, (self.threshold - .01), rolling_mean, 30)[1]
#     117
#     118             cutpoints_final = ImageColumnCropOperators.list_clean(
#
# ~/Documents/moodys_code/horizontal_crop/codebase/ImageColumnCropOperators.py in find_cutpoints(array, whiteness_threshold, axis_rollmean, gutter_threshold)
#     120         if len(sub_check_list) + 1 > gutter_threshold:
#     121             print('sub_test_running')
# --> 122             sub_check_list_clean = list_clean('sub_list', array, sub_check_list, 100, None, 8)
#     123
#     124             if len(sub_check_list_clean) + 1 > gutter_threshold:
#
# ~/Documents/moodys_code/horizontal_crop/codebase/ImageColumnCropOperators.py in list_clean(run_key, array, check_list, array_offset, column_offset, under_list_threshold)
#      81         elif run_key == 'sub_list':
#      82             for index, item in enumerate(trimmed_array.T):
# ---> 83                 if index == list_item:
#      84                     under_list = [value for value in item if value < 5]
#      85                     if len(under_list) > under_list_threshold:
#
# KeyboardInterrupt:
